# %%
import pandas as pd

#1. How do you load the IMDb dataset into a pandas DataFrame
#loading main file
file=pd.read_csv(r"F:\IMDB-Movie-Data.csv")  

#loading another file for extra needed columns
df=pd.read_csv(r"F:\movies.csv")

# adding extra columns in main file dataframe
file['Budget']=df['budget']
file['Production_companies']=df['production_companies']
file['Production_countries']=df['production_countries']
file['Original_language']=df['original_language']

#2. Display the first 5 rows of the dataset. What information can you gather from these rows?
new=file[file.index<5]
print(new) # to acceesfirst 5 rows
new.info()

#3. What method would you use to get an overview of column data types and missing values.
file.info()   # for overview of column
#for missing values
file.isnull().sum()

#4. Identify the columns with missing values. What strategies can you use to handle them?
missing_values=file.isnull().sum()
print(missing_values)

We can drop columns or rows  having missing values br using drop method or replace them by fill method..

#5. Which columns are essential for analyzing movie ratings and details? How would you drop the rest?
essential_columns = ['Title', 'Genre', 'Director', 'Actors', 'Year', 'Rating', 'Votes','Runtime (Minutes)','Revenue (Millions)']
df=file[essential_columns]   # df only contains essential columns


#6. Calculate the average runtime of movies in the dataset.
average=file['Runtime (Minutes)'].mean()
print(average)

#7. Count the number of movies in each genre. How can you present this information visually?
genre_counts =file['Genre'].value_counts()
print(genre_counts)

# To visualise we can plat the graph
# Plotting the genre distribution
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Movies in Each Genre')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()


#8. Who are the top 5 directors with the most movies in the dataset?
top_dir=file['Director'].value_counts().head(5)
print(top_dir)

#9. Create a line plot showing the number of movies released each year.
# Grouping data by year and counting the number of movies in each year
movies_per_year = file['Year'].value_counts().sort_index()

# Creating a line plot
plt.figure(figsize=(4,4))
movies_per_year.plot(kind='line', marker='o', color='blue')
plt.title('Number of Movies Released Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.tight_layout()
plt.show()


#10. Draw a histogram depicting the distribution of movie runtimes
# Extracting the 'Runtime (Minutes)' column
runtimes = file['Runtime (Minutes)']

# Creating a histogram plot
plt.figure(figsize=(4,4))
plt.hist(runtimes, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime (Minutes)')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

#11. Plot a histogram showcasing the distribution of movie rating
# Extracting the Rating column
rating = file['Rating']

# Creating a histogram plot
plt.figure(figsize=(4,4))
plt.hist(runtimes, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()


#12. Calculate the correlation coefficient between movie ratings and runtimes.
correlation=file['Rating'].corr(file['Runtime (Minutes)'])
print(correlation)

#13. Identify the 3 most frequent actors in the dataset.
top_actor=file['Actors'].value_counts().head(3)
print(top_actor)

#14. Is there any visible relationship between box office earnings and movie ratings?
plt.figure(figsize=(4,4))
plt.scatter(file["Rating"], file["Revenue (Millions)"], alpha=0.6, color='blue')
plt.xlabel("Movie Rating")
plt.ylabel("Box Office Earnings (Millions)")
plt.title("Relationship Between Movie Ratings and Box Office Earnings")
plt.grid(True)
plt.show()


#15. List the languages in which movies are released. How would you display this information as a frequency count?
# Extract the 'Language' column and calculate frequency counts
language_counts = file['Original_language'].value_counts()

# Create a DataFrame to display the frequency count information
language_counts_df = pd.DataFrame(language_counts)
language_counts_df.reset_index(inplace=True)
language_counts_df.columns = ['Original_language', 'Frequency']

# Display the DataFrame
print(language_counts_df)


#16. Plot a histogram of movie budgets to understand their distribution.
data_cleaned = file.dropna(subset=["Revenue (Millions)"])

# Create a histogram of movie budgets
plt.figure(figsize=(4,4))
plt.hist(data_cleaned["Revenue (Millions)"], bins=20, color='orange', edgecolor='black')
plt.xlabel("Revenue (Millions)")
plt.ylabel("Number of Movies")
plt.title("Distribution of Movie Budgets")
plt.grid(True)
plt.show()


#17. Which production company has produced the highest number of movies?
production_company_counts = file[ 'Production_companies'].value_counts()

# Get the production company with the highest number of movies
top_production_company = production_company_counts.idxmax()
highest_movie_count = production_company_counts.max()

# Display the result
print(f"The production company with the highest number of movies is '{top_production_company}' with {highest_movie_count} movies.")


#18. Present the distribution of movies across different countries using a bar plot

# Group the data by country and count the number of movies
country_counts = file['Production_countries'].value_counts()

# Select the top N countries for better visualization
top_countries = country_counts.head(10)  # You can adjust the number of countries to display

# Set up the Seaborn style
sns.set(style="whitegrid")

# Create a bar plot using Seaborn
plt.figure(figsize=(15,6))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title('Distribution of Movies Across Countries')
plt.xlabel('Country')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


#19. Create a word cloud visualization using movie titles or keywords from descriptions.

#20. Plot the average movie ratings over the years to identify trends
average_ratings_by_year = file.groupby("Year")["Rating"].mean()

# Plotting the average ratings over the years
plt.figure(figsize=(4,4))
plt.plot(average_ratings_by_year.index, average_ratings_by_year.values, marker='o')
plt.xlabel("Year")
plt.ylabel("Average Rating")
plt.title("Average Movie Ratings Over the Years")
plt.grid(True)
plt.show()


#21. Identify trends in average ratings over the years. What insights can you gather?
average_ratings_by_year = file.groupby("Year")["Rating"].mean()

# Create a line plot of average ratings over the years
plt.figure(figsize=(4,4))
plt.plot(average_ratings_by_year.index, average_ratings_by_year.values, marker='o', color='blue')
plt.xlabel("Year")
plt.ylabel("Average Rating")
plt.title("Trends in Average Movie Ratings Over the Years")
plt.grid(True)
plt.show()


#22. Discover the most common director-actor pairs. Who are they?
# Create a dictionary to store director-actor pairs and their counts
director_actor_pairs = {}

# Iterate through each row in the dataset
for index, row in df.iterrows():
    directors = row["Director"].split(",")
    actors = row["Actors"].split(",")

    # Generate all possible pairs of directors and actors
    pairs = [(director, actor) for director in directors for actor in actors]

    # Count the pairs
    for pair in pairs:
        if pair in director_actor_pairs:
            director_actor_pairs[pair] += 1
        else:
            director_actor_pairs[pair] = 1

# Find the most common director-actor pair
most_common_pair = max(director_actor_pairs, key=director_actor_pairs.get)
count = director_actor_pairs[most_common_pair]

# Display the most common director-actor pair
print(f"The most common director-actor pair is: {most_common_pair} with {count} occurrences.")

#23. Analyze how movie runtimes have changed over the years. Are movies getting longer or shorter?
plt.figure(figsize=(4,4))
plt.plot(average_ratings_by_year.index, average_ratings_by_year.values, marker='o', color='blue')
plt.xlabel("Year")
plt.ylabel("Runtime (Minutes)")
plt.title("Trends in Movie Runtime Over the Years")
plt.grid(True)
plt.show()

By anyalyzing above graph pattern , we can conculde that movies are getting shorter over the years.


#24. Plot the trends of different genres over the years. Which genres have become more popular?
unique_genres = set()
for genres in file["Genre"]:
    unique_genres.update(genres.split(","))

# Create a plot for each genre
plt.figure(figsize=(12, 6))
for genre in unique_genres:
    genre_data = file[file["Genre"].str.contains(genre, na=False)]
    genre_counts_by_year = genre_data.groupby("Year")["Title"].count()
    plt.plot(genre_counts_by_year.index, genre_counts_by_year.values, label=genre)

# Add labels and title
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.title("Trends of Different Genres Over the Years")
plt.legend()
plt.grid(True)
plt.show()

#By analyzing above graph pattern, Drama movies are more popular.


#25. Extract and analyze popular keywords from movie descriptions. What themes emerge?
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter



# Combine all movie descriptions into a single text
descriptions_text = ' '.join(file['Description'].dropna())

# Tokenize the text
tokens = word_tokenize(descriptions_text)

# Convert to lowercase and remove punctuation
cleaned_tokens = [token.lower() for token in tokens if token.isalnum()]

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [token for token in cleaned_tokens if token not in stop_words]

# Calculate the frequency of each word
word_frequency = Counter(filtered_tokens)

# Get the most common keywords
top_keywords = word_frequency.most_common(20)

# Print the most common keywords
print("Top Keywords:")
for keyword, frequency in top_keywords:
    print(keyword, ":", frequency)


#26. Create bar plots to compare metrics like rating, revenue, and budget. What comparisons can you make?
metrics_by_year = file.groupby("Year").agg({"Rating": "mean", "Revenue (Millions)": "mean", "Revenue (Millions)": "mean"}).reset_index()

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(4,4))

# Bar plot for average rating over the years
axes[0].bar(metrics_by_year["Year"], metrics_by_year["Rating"], color='blue')
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Average Rating")
axes[0].set_title("Average Movie Rating Over the Years")

# Bar plot for average revenue over the years
axes[1].bar(metrics_by_year["Year"], metrics_by_year["Revenue (Millions)"], color='green')
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Average Revenue (Millions)")
axes[1].set_title("Average Movie Revenue Over the Years")

# Bar plot for average budget over the years
axes[2].bar(metrics_by_year["Year"], metrics_by_year["Revenue (Millions)"], color='purple')
axes[2].set_xlabel("Year")
axes[2].set_ylabel("Average Budget (Millions)")
axes[2].set_title("Average Movie Budget Over the Years")

# Adjust layout
plt.tight_layout()
plt.show()



#27. Investigate how movie budgets relate to their earnings. Is there a pattern?
# Clean the data (remove rows with missing values in 'Budget' and 'Revenue' columns)
df_cleaned = file.dropna(subset=['Budget', 'Revenue (Millions)'])

# Create a scatter plot using Seaborn
plt.figure(figsize=(6,6))
sns.scatterplot(data=df_cleaned, x='Budget', y='Revenue (Millions)', alpha=0.7)
plt.title('Movie Budget vs. Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.xscale('log')  # Use log scale for better visualization
plt.yscale('log')
plt.tight_layout()
plt.show()

# Calculate the correlation coefficient
correlation = df_cleaned['Budget'].corr(df_cleaned['Revenue (Millions)'])
print(f"Correlation coefficient: {correlation:.2f}")

# A positive correlation between budgets and revenues suggests that, on average, 
# movies with higher budgets tend to have higher revenues......


#28. Analyze the relationship between the number of votes and movie ratings.
# Create a scatter plot of number of votes vs. ratings
plt.figure(figsize=(4,4))
plt.scatter(df["Votes"], df["Rating"], alpha=0.6, color='blue')
plt.xlabel("Number of Votes")
plt.ylabel("Movie Rating")
plt.title("Relationship Between Number of Votes and Movie Rating")
plt.grid(True)
plt.show()

#29. Explore the distribution of ratings for different genres. Are there variations?
df["Genres"] = df["Genre"].str.split(",")

# Convert the list of genres into multiple rows
df = df.explode("Genres")

# Create a box plot or violin plot of ratings for each genre
plt.figure(figsize=(4,4))
sns.boxplot(data=df, x="Genres", y="Rating")
plt.xlabel("Genre")
plt.ylabel("Rating")
plt.title("Distribution of Ratings for Different Genres")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


#30. Identify any outliers in the movie runtime data. How would you handle them?
# Extract runtime values
runtimes = file["Runtime (Minutes)"]

# Calculate quartiles and IQR
Q1 = runtimes.quantile(0.25)
Q3 = runtimes.quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = runtimes[(runtimes < lower_bound) | (runtimes > upper_bound)]

# Create a box plot to visualize the outliers
plt.figure(figsize=(8, 6))
plt.boxplot(runtimes, vert=False)
plt.xlabel("Runtime (Minutes)")
plt.title("Box Plot of Movie Runtimes")
plt.show()

# Print the list of outliers
print("Outliers in runtime data:")
print(outliers)
